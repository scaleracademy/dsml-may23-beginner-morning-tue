# %%
'''
To install pandas ->
    - pip install pandas
    - No installation needed on Colab
'''
# Out:
# '\nTo install pandas ->\n    - pip install pandas\n    - No installation needed on Colab\n'

# %%
import pandas as pd

# %%
import numpy as np

# %%
# Loading data in pandas

df = pd.read_csv("mckinsey.csv")

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.head(7)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439

# %%
df.tail(9)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1695  Zimbabwe  1967     4995432    Africa    53.995  569.795071
# 1696  Zimbabwe  1972     5861135    Africa    55.635  799.362176
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.shape # Works the same way as in Numpy
# Out:
# (1704, 6)

# %%
df.columns # dataframes have an attribute columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys() # dataframes have a method keys()
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
# Index is a special pandas object which stores immutable data

# %%
df["country"].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
type(df["country"].head())
# Out:
# pandas.core.series.Series

# %%
df[["country", "life_exp"]].head()
# Out:
#        country  life_exp
# 0  Afghanistan    28.801
# 1  Afghanistan    30.332
# 2  Afghanistan    31.997
# 3  Afghanistan    34.020
# 4  Afghanistan    36.088

# %%
type(df[["country", "life_exp"]].head())
# Out:
# pandas.core.frame.DataFrame

# %%
df[["country"]].head()
# Out:
#        country
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan

# %%
df["country"].unique()

# Returns an array of unique elements in a Series
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
type(df["country"].unique())
# Out:
# numpy.ndarray

# %%
df["country"].value_counts()

# Count of every unique element in the country column
# Out:
# country
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: count, Length: 142, dtype: int64

# %%
type(df["country"].value_counts())
# Out:
# pandas.core.series.Series

# %%
# Renaming columns

# %%
df.rename({ "population" : "POPULATION", "country" : "NATION" }, axis = 1)
# Out:
#            NATION  year  POPULATION continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename(columns = { "population" : "POPULATION", "country" : "NATION" })
# Out:
#            NATION  year  POPULATION continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({ "country" : "nation" }, axis = 1, inplace = True)

# inplace = True will ask pandas to modify the original dataframe

# %%
df
# Out:
#            nation  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
# PLEASE DO NOT DO THIS

df.nation

# PLEASE DO NOT DO THIS
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: nation, Length: 1704, dtype: object

# %%
# INSTEAD DO THIS

df["nation"]

# INSTEAD DO THIS
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: nation, Length: 1704, dtype: object

# %%
df.drop("continent", axis = 1)
# Out:
#            nation  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df
# Out:
#            nation  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop(columns = ["continent"])
# Out:
#            nation  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df
# Out:
#            nation  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop(columns = ["continent"], inplace = True)

# %%
df
# Out:
#            nation  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df["Year + 7"] = df["year"] + 7
# Pandas would do element level addition here

# %%
df.head()
# Out:
#         nation  year  population  life_exp     gdp_cap  Year + 7
# 0  Afghanistan  1952     8425333    28.801  779.445314      1959
# 1  Afghanistan  1957     9240934    30.332  820.853030      1964
# 2  Afghanistan  1962    10267083    31.997  853.100710      1969
# 3  Afghanistan  1967    11537966    34.020  836.197138      1974
# 4  Afghanistan  1972    13079460    36.088  739.981106      1979

# %%
df["gdp"] = df["gdp_cap"] * df["population"]

# %%
df
# Out:
#            nation  year  population  life_exp     gdp_cap  Year + 7
# 0     Afghanistan  1952     8425333    28.801  779.445314      1959  \
# 1     Afghanistan  1957     9240934    30.332  820.853030      1964
# 2     Afghanistan  1962    10267083    31.997  853.100710      1969
# 3     Afghanistan  1967    11537966    34.020  836.197138      1974
# 4     Afghanistan  1972    13079460    36.088  739.981106      1979
# ...           ...   ...         ...       ...         ...       ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306      1994
# 1700     Zimbabwe  1992    10704340    60.377  693.420786      1999
# 1701     Zimbabwe  1997    11404948    46.809  792.449960      2004
# 1702     Zimbabwe  2002    11926563    39.989  672.038623      2009
# 1703     Zimbabwe  2007    12311143    43.487  469.709298      2014
#
#                gdp
# 0     6.567086e+09
# 1     7.585449e+09
# 2     8.758856e+09
# 3     9.648014e+09
# 4     9.678553e+09
# ...            ...
# ...

# %%
df.drop("Year + 7", axis = 1, inplace = True)

# %%
df
# Out:
#            nation  year  population  life_exp     gdp_cap           gdp
# 0     Afghanistan  1952     8425333    28.801  779.445314  6.567086e+09
# 1     Afghanistan  1957     9240934    30.332  820.853030  7.585449e+09
# 2     Afghanistan  1962    10267083    31.997  853.100710  8.758856e+09
# 3     Afghanistan  1967    11537966    34.020  836.197138  9.648014e+09
# 4     Afghanistan  1972    13079460    36.088  739.981106  9.678553e+09
# ...           ...   ...         ...       ...         ...           ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306  6.508241e+09
# 1700     Zimbabwe  1992    10704340    60.377  693.420786  7.422612e+09
# 1701     Zimbabwe  1997    11404948    46.809  792.449960  9.037851e+09
# 1702     Zimbabwe  2002    11926563    39.989  672.038623  8.015111e+09
# 1703     Zimbabwe  2007    12311143    43.487  469.709298  5.782658e+09
#
# [1704 rows x 6 columns]

# %%
df["random"] = [ i**3 for i in range(1704) ]

# %%
df
# Out:
#            nation  year  population  life_exp     gdp_cap           gdp
# 0     Afghanistan  1952     8425333    28.801  779.445314  6.567086e+09  \
# 1     Afghanistan  1957     9240934    30.332  820.853030  7.585449e+09
# 2     Afghanistan  1962    10267083    31.997  853.100710  8.758856e+09
# 3     Afghanistan  1967    11537966    34.020  836.197138  9.648014e+09
# 4     Afghanistan  1972    13079460    36.088  739.981106  9.678553e+09
# ...           ...   ...         ...       ...         ...           ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306  6.508241e+09
# 1700     Zimbabwe  1992    10704340    60.377  693.420786  7.422612e+09
# 1701     Zimbabwe  1997    11404948    46.809  792.449960  9.037851e+09
# 1702     Zimbabwe  2002    11926563    39.989  672.038623  8.015111e+09
# 1703     Zimbabwe  2007    12311143    43.487  469.709298  5.782658e+09
#
#           random
# 0              0
# 1              1
# 2              8
# 3             27
# ...

# %%
df["weird"] = [ i**3 for i in range(1700) ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df["weird"] = [ i**3 for i in range(1700) ]
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:3960, in DataFrame.__setitem__(self, key, value)
#    3957     self._setitem_array([key], value)
#    3958 else:
#    3959     # set column
# -> 3960     self._set_item(key, value)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:4153, in DataFrame._set_item(self, key, value)
#    4143 def _set_item(self, key, value) -> None:
#    4144     """
#    4145     Add series to DataFrame in specified column.
#    4146
#    (...)
#    4151     ensure homogeneity.
#    4152     """
# -> 4153     value = self._sanitize_column(value)
#    4155     if (
#    4156         key in self.columns
#    4157         and value.ndim == 1
# ...

# %%
df["weird"] = [ i**3 for i in range(1800) ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df["weird"] = [ i**3 for i in range(1800) ]
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:3960, in DataFrame.__setitem__(self, key, value)
#    3957     self._setitem_array([key], value)
#    3958 else:
#    3959     # set column
# -> 3960     self._set_item(key, value)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:4153, in DataFrame._set_item(self, key, value)
#    4143 def _set_item(self, key, value) -> None:
#    4144     """
#    4145     Add series to DataFrame in specified column.
#    4146
#    (...)
#    4151     ensure homogeneity.
#    4152     """
# -> 4153     value = self._sanitize_column(value)
#    4155     if (
#    4156         key in self.columns
#    4157         and value.ndim == 1
# ...

# %%
df.drop(columns = ["random", "gdp"], inplace = True)

# %%
df
# Out:
#            nation  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703])

# %%
df.shape
# Out:
# (1704, 5)

# %%
df.index = np.arange(10, df.shape[0] + 10, dtype = "float")

# %%
df
# Out:
#              nation  year  population  life_exp     gdp_cap
# 10.0    Afghanistan  1952     8425333    28.801  779.445314
# 11.0    Afghanistan  1957     9240934    30.332  820.853030
# 12.0    Afghanistan  1962    10267083    31.997  853.100710
# 13.0    Afghanistan  1967    11537966    34.020  836.197138
# 14.0    Afghanistan  1972    13079460    36.088  739.981106
# ...             ...   ...         ...       ...         ...
# 1709.0     Zimbabwe  1987     9216418    62.351  706.157306
# 1710.0     Zimbabwe  1992    10704340    60.377  693.420786
# 1711.0     Zimbabwe  1997    11404948    46.809  792.449960
# 1712.0     Zimbabwe  2002    11926563    39.989  672.038623
# 1713.0     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.index[1]

# df.index[implicit_index] -> Explicit Index
# Out:
# 11.0

# %%
sample = df.head()

# %%
sample
# Out:
#            nation  year  population  life_exp     gdp_cap
# 10.0  Afghanistan  1952     8425333    28.801  779.445314
# 11.0  Afghanistan  1957     9240934    30.332  820.853030
# 12.0  Afghanistan  1962    10267083    31.997  853.100710
# 13.0  Afghanistan  1967    11537966    34.020  836.197138
# 14.0  Afghanistan  1972    13079460    36.088  739.981106

# %%
sample.index = ["a", "b", "c", "d", "e"]

# %%
sample
# Out:
#         nation  year  population  life_exp     gdp_cap
# a  Afghanistan  1952     8425333    28.801  779.445314
# b  Afghanistan  1957     9240934    30.332  820.853030
# c  Afghanistan  1962    10267083    31.997  853.100710
# d  Afghanistan  1967    11537966    34.020  836.197138
# e  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.index = np.arange(10, df.shape[0] + 10, dtype = "int")

# %%
df
# Out:
#            nation  year  population  life_exp     gdp_cap
# 10    Afghanistan  1952     8425333    28.801  779.445314
# 11    Afghanistan  1957     9240934    30.332  820.853030
# 12    Afghanistan  1962    10267083    31.997  853.100710
# 13    Afghanistan  1967    11537966    34.020  836.197138
# 14    Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1709     Zimbabwe  1987     9216418    62.351  706.157306
# 1710     Zimbabwe  1992    10704340    60.377  693.420786
# 1711     Zimbabwe  1997    11404948    46.809  792.449960
# 1712     Zimbabwe  2002    11926563    39.989  672.038623
# 1713     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df[14]

# Pandas thinks that it has to search a column with label 14
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 14
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
s1 = df["nation"]

# %%
s1
# Out:
# 10      Afghanistan
# 11      Afghanistan
# 12      Afghanistan
# 13      Afghanistan
# 14      Afghanistan
#            ...
# 1709       Zimbabwe
# 1710       Zimbabwe
# 1711       Zimbabwe
# 1712       Zimbabwe
# 1713       Zimbabwe
# Name: nation, Length: 1704, dtype: object

# %%
s1[20] # Indexing - Explicit Indexes
# Out:
# 'Afghanistan'

# %%
s1[20:24] # Slicing - Implicit Indexes
# Out:
# 30    Albania
# 31    Albania
# 32    Albania
# 33    Albania
# Name: nation, dtype: object

# %%
# loc (location) -> Explicit Indexes
# iloc (implicit location) -> Implicit Indexes

# %%
df
# Out:
#            nation  year  population  life_exp     gdp_cap
# 10    Afghanistan  1952     8425333    28.801  779.445314
# 11    Afghanistan  1957     9240934    30.332  820.853030
# 12    Afghanistan  1962    10267083    31.997  853.100710
# 13    Afghanistan  1967    11537966    34.020  836.197138
# 14    Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1709     Zimbabwe  1987     9216418    62.351  706.157306
# 1710     Zimbabwe  1992    10704340    60.377  693.420786
# 1711     Zimbabwe  1997    11404948    46.809  792.449960
# 1712     Zimbabwe  2002    11926563    39.989  672.038623
# 1713     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.loc[25]
# Out:
# nation            Albania
# year                 1967
# population        1984060
# life_exp            66.22
# gdp_cap       2760.196931
# Name: 25, dtype: object

# %%
df.loc[1:3]
# Out:
# Empty DataFrame
# Columns: [nation, year, population, life_exp, gdp_cap]
# Index: []

# %%
df.loc[10:16] # Ending point included
# Out:
#          nation  year  population  life_exp     gdp_cap
# 10  Afghanistan  1952     8425333    28.801  779.445314
# 11  Afghanistan  1957     9240934    30.332  820.853030
# 12  Afghanistan  1962    10267083    31.997  853.100710
# 13  Afghanistan  1967    11537966    34.020  836.197138
# 14  Afghanistan  1972    13079460    36.088  739.981106
# 15  Afghanistan  1977    14880372    38.438  786.113360
# 16  Afghanistan  1982    12881816    39.854  978.011439

# %%
'''
IMPORTANT NOTE (Only applies to explicit indexes) ->

SLICING USING df.loc[star:end]
    - Start point is included
    - End point is also included
'''
# Out:
# '\nIMPORTANT NOTE (Only applies to explicit indexes) ->\n\nSLICING USING df.loc[star:end]\n    - Start point is included\n    - End point is also included\n'

# %%
df.iloc[1:5]
# Out:
#          nation  year  population  life_exp     gdp_cap
# 11  Afghanistan  1957     9240934    30.332  820.853030
# 12  Afghanistan  1962    10267083    31.997  853.100710
# 13  Afghanistan  1967    11537966    34.020  836.197138
# 14  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.iloc[6]
# Out:
# nation        Afghanistan
# year                 1982
# population       12881816
# life_exp           39.854
# gdp_cap        978.011439
# Name: 16, dtype: object

# %%
df.iloc[[1, 10, 100]]
# Out:
#           nation  year  population  life_exp     gdp_cap
# 11   Afghanistan  1957     9240934    30.332  820.853030
# 20   Afghanistan  2002    25268405    42.129  726.734055
# 110   Bangladesh  1972    70759295    45.252  630.233627

# %%
df.iloc[-1]
# Out:
# nation          Zimbabwe
# year                2007
# population      12311143
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1713, dtype: object

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.drop("index", axis = 1, inplace = True)

# %%
df
# Out:
#            nation  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.loc[-1:-3]
# Out:
# Empty DataFrame
# Columns: [nation, year, population, life_exp, gdp_cap]
# Index: []
