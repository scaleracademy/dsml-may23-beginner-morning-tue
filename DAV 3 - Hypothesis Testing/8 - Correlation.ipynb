# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_hw = pd.read_csv("weight-height.csv")

# %%
df_hw
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
sns.scatterplot(x = df_hw["Height"], y = df_hw["Weight"])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
df_hw["Height"].mean()
# Out:
# 66.36755975482124

# %%
df_hw["Weight"].mean()
# Out:
# 161.44035683283076

# %%
df_hw["Height_m"] = df_hw["Height"] / 12

# %%
df_hw["Weight_g"] = df_hw["Weight"] * 453

# %%
df_hw.head()
# Out:
#   Gender     Height      Weight  Height_m       Weight_g
# 0   Male  73.847017  241.893563  6.153918  109577.784121
# 1   Male  68.781904  162.310473  5.731825   73526.644052
# 2   Male  74.110105  212.740856  6.175842   96371.607567
# 3   Male  71.730978  220.042470  5.977582   99679.239047
# 4   Male  69.881796  206.349801  5.823483   93476.459683

# %%
sns.scatterplot(x = df_hw["Height"], y = df_hw["Weight_g"])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight_g'>

# %%
df_hw[["Height", "Weight"]].corr()
# Out:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000

# %%
'''
Positive Correlation
    - Increase Increase
    - Decrease Decrease

Negative Correlation
    - Increase Decrease
    - Decrease Increase

No Correlation
    - No Change
'''
# Out:
# '\nPositive Correlation\n    - Increase Increase\n    - Decrease Decrease\n\nNegative Correlation\n    - Increase Decrease\n    - Decrease Increase\n\nNo Correlation\n    - No Change\n'

# %%
age = [14, 25, 20, 35, 45, 30, 60, 95]
reaction_times = [12, 15, 17, 18, 20, 21, 22, 26]

# %%
sns.scatterplot(x = age, y = reaction_times)
# Out:
# <AxesSubplot:>

# %%
age_ranks = [1, 3, 2, 5, 6, 4, 7, 8]
reaction_time_ranks = [1, 2, 3, 4, 5, 6, 7, 8]

# %%
sns.scatterplot(x = age_ranks, y = reaction_time_ranks)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Spearman Correlation -
#
# - Assigns ranks to all data points in cases where the relationship between variables is not linear.
# - Converts non - linear relationships to linear relationships
# - Converts unranked (nominal) data to ranked (ordinal) data

# %%
from scipy.stats import pearsonr, spearmanr

# %%
pearsonr(df_hw["Height"], df_hw["Weight"])
# Out:
# (0.924756298740915, 0.0)

# %%
spearmanr(df_hw["Height"], df_hw["Weight"])
# Out:
# SpearmanrResult(correlation=0.9257076644210767, pvalue=0.0)

# %%
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]

# %%
spearmanr(x, y)
# Out:
# SpearmanrResult(correlation=-0.9999999999999999, pvalue=1.4042654220543672e-24)

# %%
df = pd.read_csv("concrete_data.csv")

# %%
df.head()
# Out:
#    cement  blast_furnace_slag  fly_ash  water  superplasticizer
# 0   540.0                 0.0      0.0  162.0               2.5  \
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 0            1040.0            676.0   28                          79.99
# 1            1055.0            676.0   28                          61.89
# 2             932.0            594.0  270                          40.27
# 3             932.0            594.0  365                          41.05
# 4             978.4            825.5  360                          44.30

# %%
plt.figure(figsize = (10, 8))
correlation_values = df.corr(method = "pearson")
sns.heatmap(
    correlation_values,
    vmax = 0.6,
    linewidths = 0.01,
    square = True,
    annot = True,
    cmap = "RdBu",
    linecolor = "black"
)
plt.title("Correlation between Concrete features")
plt.show()
